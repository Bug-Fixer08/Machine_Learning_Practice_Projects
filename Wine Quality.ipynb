# %% [markdown]
# # Analysis of Quality of Wine Dataset

# %% [markdown]
# Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the Quality of Wine Dataset

# %%
df=pd.read_csv('wine dataset.csv')

# %% [markdown]
# Checking The Wine Dataset

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# So we can see that there are 1599 Rows or 1599 wine samples and 12 Columns or Attributes

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# All the Data Present in Wine Dataset are Numerical.The target column 'quality' has integer values and remaining all columns have float values

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# As we can see that All the columns in Wine Dataset has no null values.So we didn't have to replace values.

# %% [markdown]
# Observation:
#
# Outliers present in free sulfur dioxide and total sulfur dioxide.
# Maximum features are normally distributed

# %%
#import Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('Null Values Using Heatmap')
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:title={'center':'Null Values Using Heatmap'}>

# %% [markdown]
# As wecan saw that there are no light colors in the heatmap,so there are no null values

# %%
#Getting Statiscal Summery
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Outliers present
#
# All the features are appoximately normal distributed.

# %% [markdown]
# # Checking Distribution

# %%
plt.figure(figsize=(15,14))
plot=1
for i in df:
    if plot<=10:
        plt.subplot(4,3,plot)
        sns.distplot(df[i])
        plt.xlabel(i)
    plot=plot+1
plt.show()

# %% [markdown]
# ### Checking correlation

# %%
plt.figure(figsize=(12,8))
plt.title('Correlation Heatmap',fontsize=15)
sns.heatmap(df.corr(),annot=True,cmap='RdYlBu_r')
# Out:
# <AxesSubplot:title={'center':'Correlation Heatmap'}>

# %%
df['fixed acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['quality'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cheaking outliers

# %%
plt.figure(figsize=(15,14))
plot=1
for i in df:
    if plot<=12:
        plt.subplot(4,3,plot)
        sns.boxplot(df[i])
        plt.xlabel(i)
    plot=plot+1
plt.show()

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z_score=zscore(df)
print(df.shape)
df_1=df.loc[(z_score<3.5).all(axis=1)]
print(df_1.shape)
# Out:
# (1599, 12)
# (1518, 12)

# %%
## Alter removal of  very distinct datapoints
plt.figure(figsize=(15,14))
plot=1
for i in df_1:
    if plot<=12:
        plt.subplot(4,3,plot)
        sns.boxplot(df_1[i])
        plt.xlabel(i)
    plot=plot+1
plt.show()

# %% [markdown]
# # Skewness

# %%
df_1.skew()
# Out:
# fixed acidity           0.838429
# volatile acidity        0.444226
# citric acid             0.299264
# residual sugar          2.452040
# chlorides               2.635851
# free sulfur dioxide     0.989073
# total sulfur dioxide    1.198312
# density                -0.078641
# pH                      0.153646
# sulphates               1.012281
# alcohol                 0.833944
# quality                 0.264507
# dtype: float64

# %%
## If skewness must be -.5<skew<.5
for col in df_1:
    if df_1[col].skew()>=.5:
        df_1[col]=np.cbrt(df_1[col])

# %%
## Skewness Removed
df_1.skew()
# Out:
# fixed acidity           0.513421
# volatile acidity        0.444226
# citric acid             0.299264
# residual sugar          1.624731
# chlorides               1.064674
# free sulfur dioxide     0.175154
# total sulfur dioxide    0.353578
# density                -0.078641
# pH                      0.153646
# sulphates               0.594450
# alcohol                 0.704530
# quality                 0.264507
# dtype: float64

# %%
## Checking unique values in Target column
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
## Set a cutoff to convert multiclass class classification to Binary Class.
bins=[2,6,9]
labels=['Bad','Good']
df_1['quality']=pd.cut(df_1['quality'],bins=bins,labels=labels)
df_1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       1.948695              0.70         0.00        1.238562   0.423582
# 1       1.983192              0.88         0.00        1.375069   0.461044
# 2       1.983192              0.76         0.04        1.320006   0.451436
# 3       2.237378              0.28         0.56        1.238562   0.421716
# 4       1.948695              0.70         0.00        1.238562   0.423582
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0             2.223980              3.239612   0.9978  3.51   0.824257
# 1             2.924018              4.061548   0.9968  3.20   0.879366
# 2             2.466212              3.779763   0.9970  3.26   0.866239
# 3             2.571282              3.914868   0.9980  3.16   0.833955
# 4             2.223980              3.239612   0.9978  3.51   0.824257
#
#     alcohol quality
# 0  2.110454     Bad
# 1  2.139975     Bad
# 2  2.139975     Bad
# ...

# %%
df_1['quality'].value_counts()
# Out:
# Bad     1311
# Good     207
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title('Distribution of Target',fontsize=15)
sns.countplot(df_1['quality'])
# Out:
# <AxesSubplot:title={'center':'Distribution of Target'}, xlabel='quality', ylabel='count'>

# %% [markdown]
# It Shows distribution is imbalanced

# %% [markdown]
# # Encoding the target Variable

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_1['quality']=le.fit_transform(df_1['quality'])

# %%
df_1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       1.948695              0.70         0.00        1.238562   0.423582
# 1       1.983192              0.88         0.00        1.375069   0.461044
# 2       1.983192              0.76         0.04        1.320006   0.451436
# 3       2.237378              0.28         0.56        1.238562   0.421716
# 4       1.948695              0.70         0.00        1.238562   0.423582
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0             2.223980              3.239612   0.9978  3.51   0.824257
# 1             2.924018              4.061548   0.9968  3.20   0.879366
# 2             2.466212              3.779763   0.9970  3.26   0.866239
# 3             2.571282              3.914868   0.9980  3.16   0.833955
# 4             2.223980              3.239612   0.9978  3.51   0.824257
#
#     alcohol  quality
# 0  2.110454        0
# 1  2.139975        0
# ...

# %% [markdown]
# # Separating X an Y Values

# %%
df_x=df_1.drop(['quality'],axis=1)
y=df_1[['quality']]

# %%
df_x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          1.948695             0.700         0.00        1.238562   0.423582
# 1          1.983192             0.880         0.00        1.375069   0.461044
# 2          1.983192             0.760         0.04        1.320006   0.451436
# 3          2.237378             0.280         0.56        1.238562   0.421716
# 4          1.948695             0.700         0.00        1.238562   0.423582
# ...             ...               ...          ...             ...        ...
# 1594       1.837091             0.600         0.08        1.259921   0.448140
# 1595       1.806969             0.550         0.10        1.300591   0.395789
# 1596       1.846915             0.510         0.13        1.320006   0.423582
# 1597       1.806969             0.645         0.12        1.259921   0.421716
# 1598       1.817121             0.310         0.47        1.532619   0.406155
#
# ...

# %%
y
# Out:
#       quality
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1594        0
# 1595        0
# 1596        0
# 1597        0
# 1598        0
#
# [1518 rows x 1 columns]

# %%
y.value_counts()
# Out:
# quality
# 0          1311
# 1           207
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.506616          1.008962    -1.386904       -0.609450  -0.211354
# 1         -0.246527          2.053594    -1.386904        0.352108   0.790531
# 2         -0.246527          1.357173    -1.177981       -0.035757   0.533572
# 3          1.669875         -1.428513     1.538023       -0.609450  -0.261260
# 4         -0.506616          1.008962    -1.386904       -0.609450  -0.211354
# ...             ...               ...          ...             ...        ...
# 1513      -1.348047          0.428611    -0.969058       -0.458999   0.445442
# 1514      -1.575146          0.138436    -0.864596       -0.172515  -0.954670
# 1515      -1.273978         -0.093705    -0.707903       -0.035757  -0.211354
# 1516      -1.575146          0.689769    -0.760134       -0.458999  -0.261260
# 1517      -1.498608         -1.254407     1.067945        1.461897  -0.677446
#
# ...

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
mod=ExtraTreesClassifier()
mod.fit(x,y)
print(mod.feature_importances_)
feat_importances=pd.Series(mod.feature_importances_,index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.07142583 0.09947521 0.09490082 0.07417135 0.07196908 0.06696703
#  0.07950854 0.08741504 0.06778177 0.11274895 0.17363639]

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,auc,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Finding Best Random Value for Max Accuracy

# %%
maxAccu=0
maxRS=0


for i in range (1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lr=LogisticRegression()
    
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print('Best accuracu is',maxAccu,'on Random State',maxRS)
# Out:
# Best accuracu is 0.9157894736842105 on Random State 46

# %% [markdown]
# ### Model Trainning

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=46,stratify=y)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1138, 11) (380, 11) (1138, 1) (380, 1)

# %%
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
rfc=RandomForestClassifier()
svc=SVC()

# %%
models=[]
models.append(('LogisticRegression',lr))
models.append(('SVC',svc))
models.append(('RandomForestClassifier',rfc))
models.append(('DecisionTreeClassifier',dtc))
models.append(('KNeighborsClassifier',knn))

# %%
Model=[]
score=[]
CVS=[]
rocscore=[]
for name,model in models:
    print(name)
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_Val_Score=',sc)
    CVS.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# LogisticRegression
#
#
# LogisticRegression()
#
#
# Accuracy_score= 0.8710526315789474
#
#
# Cross_Val_Score= 0.8741896131056116
#
#
# roc_auc_score= 0.674484052532833
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       328
#            1       0.54      0.40      0.46        52
#
#     accuracy                           0.87       380
#    macro avg       0.72      0.67      0.69       380
# weighted avg       0.86      0.87      0.86       380
#
#
#
# [[310  18]
#  [ 31  21]]
#
#
#
#
#
# SVC
#
#
# SVC()
#
#
# Accuracy_score= 0.8710526315789474
#
#
# Cross_Val_Score= 0.8787948762635065
#
#
# roc_auc_score= 0.6340290806754221
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       328
#            1       0.55      0.31      0.40        52
#
#     accuracy                           0.87       380
# ...

# %%
result = pd.DataFrame({'Model':Model,'Accuracy_score': score,'cross_val_score':CVS,'Roc_auc_curve':rocscore})
result
# Out:
#                     Model  Accuracy_score  cross_val_score  Roc_auc_curve
# 0      LogisticRegression       87.105263        87.418961      67.448405
# 1                     SVC       87.105263        87.879488      63.402908
# 2  RandomForestClassifier       88.157895        88.077727      67.249062
# 3  DecisionTreeClassifier       84.736842        84.388289      69.312852
# 4    KNeighborsClassifier       86.052632        85.441792      64.411351

# %% [markdown]
# # Random Forest Classifier Performs Best

# %% [markdown]
# Saving The Best Model

# %%
import joblib

# %%
joblib.dump(rfc, 'Winequality_rfc.pkl')
# Out:
# ['Winequality_rfc.pkl']
